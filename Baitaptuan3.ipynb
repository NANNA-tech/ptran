# %%
#W3A2
a=int(input("Nhập a: "))
b=int(input("Nhập b: "))
a= a^b   #XOR lần 1
b=a^b     #XOR lần 2
a=a^b     #XOR lần 2    
print("Sau khi đổi: a=", a, ",b =",b)
# Out:
# Sau khi đổi: a= 3 ,b = 5

# %%
#
x = int(input("Nhập x: "))
y = int(input("Nhập y: "))

print("x AND y =", x & y)
print("x OR y =", x | y)
print("x XOR y =", x ^ y)
# Out:
# x AND y = 8
# x OR y = 11
# x XOR y = 3

# %%
#W3A4
a = float(input("Nhập a: "))
b = float(input("Nhập b: "))
kq = a // b
print("Kết quả làm tròn xuống=", kq)
# Out:
# Kết quả làm tròn xuống= 1.0
