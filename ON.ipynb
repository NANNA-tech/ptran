# %%
def fun():
    print(10)

x = fun()  # Màn hình hiện 10 (do lệnh print bên trong hàm)
print("---")
print(x)   # Màn hình hiện None (vì x thực chất đang giữ giá trị None)
# Out:
# 10
# ---
# None
