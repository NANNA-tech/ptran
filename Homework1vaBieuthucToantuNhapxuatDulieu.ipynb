# %%
# Bài 1
n = int(input("Nhập vào số nguyên n: "))  
print("Số gấp đôi của n là:", n * 2)
# Out:
# Số gấp đôi của n là: 18

# %%
# Bài 2
a = float(input("Nhập chiều rộng (a): "))
b = float(input("Nhập chiều dài (b): "))
r = float(input("Nhập bán kính khu vui chơi (r): "))

S_dat = a * b                
S_tron = 3.14 * r ** 2       
S_conlai = S_dat - S_tron   

print("Phần diện tích đất còn lại là:", round(S_conlai, 2))
# Out:
# Phần diện tích đất còn lại là: 20.38

# %%
# Bài 3
c = input("Nhập 1 ký tự: ")

if c.isupper():                      # Nếu là chữ in hoa
    print("Chữ thường tương ứng là:", c.lower())
elif c.islower():                    # Nếu là chữ thường
    print("Chữ hoa tương ứng là:", c.upper())
else:
    print("Ký tự không phải là chữ cái.")
# Out:
# Chữ hoa tương ứng là: U

# %%
# Bài 4
c = input("Nhập 1 ký tự: ")

if c.isalpha():       # isalpha() kiểm tra có phải là chữ cái (A-Z, a-z)
    print(f"{c} là ký tự alphabet.")
else:
    print(f"{c} không phải là ký tự alphabet.")
# Out:
# u là ký tự alphabet.

# %%
# Bài 5
A = input("Nhập vào một chữ cái hoa (A-Z): ")

if A == 'A':
    print("Chữ cái liền trước là: Z")
else:
    truoc = chr(ord(A) - 1)  # Lùi lại 1 ký tự trong bảng mã ASCII
    print("Chữ cái liền trước là:", truoc)
# Out:
# Chữ cái liền trước là: X

# %%
# Bài 6
a = float(input("Nhập cạnh a: "))
b = float(input("Nhập cạnh b: "))
c = float(input("Nhập cạnh c: "))

if a + b > c and a + c > b and b + c > a:
    p = (a + b + c) / 2
    S = (p * (p - a) * (p - b) * (p - c)) ** 0.5
    print("Diện tích tam giác là:", round(S, 3))
else:
    print("Ba cạnh này không tạo thành tam giác.")
# Out:
# Diện tích tam giác là: 34.197

# %%
# Bài 7
s = input("Nhập chuỗi ký tự thường (>=20 ký tự): ")

if len(s) >= 20:
    print("Các ký tự từ thứ 5 đến thứ 9 là:", s[4:9])
else:
    print("Chuỗi quá ngắn! Hãy nhập ít nhất 20 ký tự.")
# Out:
# Các ký tự từ thứ 5 đến thứ 9 là: 3hfsd

# %%
# Bài 8
ten = input("Tên chủ hộ: ")
cu = int(input("Chỉ số tháng trước: "))
moi = int(input("Chỉ số tháng này: "))

dien = moi - cu

if dien <= 50:
    tien = dien * 1984
elif dien <= 100:
    tien = 50 * 1984 + (dien - 50) * 2050
elif dien <= 200:
    tien = 50 * 1984 + 50 * 2050 + (dien - 100) * 2830
elif dien <= 300:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2830 + (dien - 200) * 2997
elif dien <= 400:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2830 + 100 * 2997 + (dien - 300) * 3350
else:
    tien = (50 * 1984 + 50 * 2050 + 100 * 2830 + 100 * 2997 +
            100 * 3350 + (dien - 400) * 3460)

# Tính VAT 8%
tong = round(tien * 1.08)

# In kết quả
print(f"Họ và tên: {ten}")
print(f"Tiền phải trả: {tong} đồng")
# Out:
# Họ và tên: Nguyễn Phương A
# Tiền phải trả: 127062 đồng

# %% [markdown]
# Một số bài tập khác:

# %%
#1
n = int(input("Nhập số nguyên: "))
if n % 2 == 0:
    print("Số chẵn")
else:
    print("Số lẻ")
# Out:
# Số chẵn

# %%
#2
n = int(input("Nhập số nguyên: "))
cuoi = n % 10
if cuoi == 5:
    print("True")
else:
    print("False")
# Out:
# True

# %%
#3
n = int(input("Nhập số: "))
if n % 3 == 0 and n % 5 == 0:
    print("True")
else:
    print("False")
# Out:
# False

# %%
#4
nam_sinh = int(input("Nhập năm sinh: "))
tuoi = 2025 - nam_sinh 
if tuoi >= 18:
    print(f"Bạn {tuoi} tuổi: Đủ tuổi đi bầu cử")
else:
    print(f"Bạn {tuoi} tuổi: Chưa đủ tuổi bầu cử")
# Out:
# Bạn 18 tuổi: Đủ tuổi đi bầu cử

# %%
#5
a=float(input("Nhập số thứ nhất: "))
b=float(input("Nhập số thứ hai: "))
if a==b:
   print("Hai số bằng nhau")
else:
   if a>b:
      print("Số lớn hơn là: ", a)
   else:
      print("Số lơn hơn là: ", b)
# Out:
# Số lơn hơn là:  9.0

# %%
#6
s=input("Nhập 1 ký tự: ")
if s.isalpha():
    print("Ký tự này là chữ cái")
elif s.isdigit():
    print("Ký tự này là số")
else:
    print("Ký tự này không phải chữ cái hoặc số")
# Out:
# Ký tự này là chữ cái

# %%
#7
d = float(input("Nhập điểm: "))
if d >= 8:
    print("Giỏi")
elif d >= 6.5:
    print("Khá")
elif d >= 5:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Giỏi

# %%
#8
nam = int(input("Nhập năm: "))
if (nam % 400 == 0) or (nam % 4 == 0 and nam % 100 != 0):
    print("Năm nhuận")
else:
    print("Không nhuận")
# Out:
# Không nhuận

# %%
#9
n = int(input("Nhập số 0–9: "))
so = ["Không", "Một", "Hai", "Ba", "Bốn", "Năm", "Sáu", "Bảy", "Tám", "Chín"]
if 0 <= n <= 9:
    print(so[n])
else:
    print("Ngoài phạm vi")
# Out:
# Một

# %%
#Cách 2
n=int(input("Nhập 1 số nguyên 0-9: "))
match n:
    case 0:
        print("Không")
    case 1:
        print("Một")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bốn")
    case 5:
        print("Năm")
    case 6:
        print("Sáu")
    case 7:
        print("Bảy")
    case 8:
        print("Tám")
    case 9:
        print("Chín")
    case _:
        print("Không hợp lệ! Vui lòng nhập số 0-9.")
# Out:
# Một

# %%
#10
d = float(input("Nhập điểm: "))
if 10>=a>=4:
    print("Qua môn")
elif 0<=a<=4:
    print("Học lại")
else:
    print("Điểm không hợp lệ, vui lòng nhập lại!")
# Out:
# Qua môn

# %%
#11
n = int(input("Nhập năm sinh: "))
tuoi = 2025 - n
print("Tuổi: ", tuoi)
if tuoi >=18:
    print("Đã đủ 18 tuổi")
else:
    print("Chưa đủ 18 tuổi")
# Out:
# Tuổi:  18
# Đã đủ 18 tuổi

# %% [markdown]
# ----Biểu thức toán tử, nhập suất dữ liệu-----

# %%
# W2A1
print("Hello World!")
# Out:
# Hello World!

# %%
# W2A2
name = input("Nhập tên: ")
print("Xin chào", name)
# Out:
# Xin chào Trang

# %%
# W2A3
a, b = map(int, input().split())
print(a + b)
print(a - b)
print(a * b)
print(a//b)
print(a%b)
print(f"{a/b:.2f}")
# Out:
# 7
# 3
# 10
# 2
# 1
# 2.50

# %%
# W2A4
a1, b1, c1, a2, b2, a3 = map(float, input().split())
TB = ((a1 + b1 + c1) + (a2 + b2) * 2 + a3 * 3)/10
print(round(TB,1))
# Out:
# 9.3

# %%
# W2A5
a, b = map(int, input(). split())
print(a**b)
# Out:
# 8

# %%
# W2A6
kytuthuong = input()
maunicode = ord(kytuthuong)
print("ma unicode la:", maunicode)
kytuhoa = kytuthuong.upper()
print("ky tu hoa la:", kytuhoa)
# Out:
# ma unicode la: 105
# ky tu hoa la: I

# %%
# Cách 2
c = input()
print(ord(c))
c_hoa = chr(ord(c)-32)
print(c_hoa)
# Out:
# 101
# E

# %%
#W2A7
A = ((13**2)*3)+5
B = 13**2*3+5

print("A=", A)
print("B=", B)
# Out:
# A= 512
# B= 512

# %%
#W2A8
C=float(input("Nhập độ C: "))
fahrenheit=(9/5 * C) + 32
print(f"Nhiệt độ F là: {fahrenheit: .2f}")
# Out:
# Nhiệt độ F là:  170.24

# %%
#W2A9
x=float(input("Nhập giá đồng hồ (USD): "))

phi_ship = 10
thue_nhap_canh = x * 0.30
thue_vat= x * 0.10

tong_tien = x + phi_ship + thue_nhap_canh + thue_vat

print(f"Tổng số tiền mà Đạt phải trả là: {tong_tien:.2f} USD")
# Out:
# Tổng số tiền mà Đạt phải trả là: 49.20 USD

# %%
#W2A10
name = input(".split()")

list = name.split()

name_1 = list[0]
name_2 = list[1]
name_3 = list[2]

print(f"Hi {name_3}, {name_2} and {name_1}.")
# Out:
# Hi Jin, Tom and Jay.

# %%
#W2A11
h = int(input("Nhập số giờ: "))
m = int(input("Nhập số phút: "))

tong_giay = (h*3600) + (m*60)

print(f"Tổng số giây là: {tong_giay}")
# Out:
# Tổng số giây là: 14820

# %%
#W2A12
n = int(input("Nhập độ dài cạnh Rubik: "))

mieng_dan = 6*(n**2)

print("Tổng số miếng dán là: ", mieng_dan)
# Out:
# Tổng số miếng dán là:  24

# %%
#W2A13
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))

thuong = a // b
du = a % b

print("Thương =", thuong)
print("Số dư =", du)
# Out:
# Thương = 4
# Số dư = 16

# %%
#W2A14
a = int(input("a = "))
b = int(input("b = "))

a, b = b, a

print("Sau khi đổi: a =", a, ", b =", b)
# Out:
# Sau khi đổi: a = 128 , b = 67

# %%
#W2A15
n = int(input("Nhập n: "))
so_sao = 6 * n * (n-1) + 1
print(f"Số sao thứ {n} là: {so_sao} ")
# Out:
# Số sao thứ 7 là: 253

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("*\n***\n*****")
# Out:
# *
# ***
# *****

# %%
#W2A18
print("### # #   ### ###\n #  #  #   #   #\n #  #   #  #   #\n #  #  #   #   #\n #  # #    #   #")
# Out:
# ### # #   ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  # #    #   #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(10):
 print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world

# %%
#Cách 2
count = 0
while count <= 9 :
     print("Hello, world")
     count += 1
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world

# %%
#Cách 3
lines = ["Hello, world"] * 10
print("\n".join(lines))
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world

# %%
#Cách 4
print(*["Hello, world"]*10, sep="\n")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world

# %%
#In kèm số thứ tự
for i in range(1, 11):
    print(f"{i}. Hello, world")
# Out:
# 1. Hello, world
# 2. Hello, world
# 3. Hello, world
# 4. Hello, world
# 5. Hello, world
# 6. Hello, world
# 7. Hello, world
# 8. Hello, world
# 9. Hello, world
# 10. Hello, world

# %%
#In trên 1 dòng
print("Hello, world. " * 10)
# Out:
# Hello, world. Hello, world. Hello, world. Hello, world. Hello, world. Hello, world. Hello, world. Hello, world. Hello, world. Hello, world.
